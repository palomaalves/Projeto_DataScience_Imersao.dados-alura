# %% [markdown]
# <a href="https://colab.research.google.com/github/palomaalves/imersao.dados-alura/blob/main/Imersao_Dados_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##ANÁLISE DE DADOS PYTHON

# %% [markdown]
# #Aula 01
#
# PYTHON, PANDAS E PHARMACIA
#
# Na aula 01 foi explorarado um conjunto de dados relacionados à industria farmacêutica. Para isso foi utilizado uma biblioteca muito conhecida no mundo de DataScience, o Pandas, para abrir o dataset, que está no formato CSV e para gerar um dataframe, uma tabela, com obejtivo de analisar e entender o que significava cada coluna.
#
# Foram analisadas cada coluna de forma separada e também foram gerados alguns gráficos.
#
# Utilizou-se:
#
# - id : identificador para um experimento
# - G's : expressão gênica = Processo pelo qual a informação hereditária de um gene, forma uma proteína ou RNA
# - C's : viabilidade celular = Analisar células de uma cultura celular, afim de avaliar sua atividade.
# - composto / droga = Placebo (talvez) para casos com controle e remédios / substâncias diferentes para casos com droga
# - MOA : Mecanismo de ação do Alvo : interação bioquímica entre uma droga utilizada e um alvo (enzima (terminados com -ase), proteína, etc).

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0']>0]

# %%
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados.tail(5)
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
qtde_drogas = len(dados.droga.unique())
print(f'{qtde_drogas} drogas foram analisadas.')
# Out:
# 3289 drogas foram analisadas.

# %%
dados.columns = [x.replace('-', '')for x in dados.columns]
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
mapa = {'droga':'composto'}
dados.rename(columns=mapa, inplace = True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos= dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 Compostos')
plt.show()

# %% [markdown]
# #### Desafio 01: Ordenar o gráfico countplot
# #### Desafio 02: Melhorar a fonte e a visualização do gráfico

# %%
sns.set()
plt.figure(figsize=(8, 6))
#plt.title('')
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'), order= cod_compostos, palette ='gray')
ax.set_title('Os Compostos mais utilizados', fontsize=16)
plt.ylabel('Valor', fontsize=12, fontweight = "bold")
plt.xlabel('Composto', fontsize=12, fontweight = "bold")

plt.show()

# %% [markdown]
# #Aula 2
#
# ESTATISTICAS, DADOS E DISTRIBUIÇÃO
#
# Foram utlizadas as bibliotecas do seaborn e matplotlib para plotar e estilizar gráficos, utilizando recursos de seleção e tratamentos nos dados. Também foi utilizado o histograma para visualizar a média dos genes, com a função describe para descrever estatisticamente os dados. Por fim, o boxplot e tratamento dos outliers.

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].hist(bins = 50)

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g0', 'g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:, 'g0':'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:, 'g0':'g771'].describe().T['mean'].hist(bins=30)

# %%
dados.loc[:, 'g0':'g771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:, 'g0':'g771'].describe().T['max'].hist(bins=30)

# %% [markdown]
# #### Desafio 03: Plotar os Histogramas com o Seaborn

# %%
#dados['g-0'].hist(bins=50)
plt.figure(figsize=(8,6))
plt.title('Histograma Composto g0',fontsize=16, fontweight = "bold")
plt.ylabel('Quantidade', fontsize=12, fontweight = "bold")
plt.xlabel('Composto', fontsize=12, fontweight = "bold")

sns.histplot(data=dados['g0'],bins=50)

# %%
# Configurando a estrutura dos gráficos
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(16,8))
plt.subplots_adjust(hspace=0.4)
plt.suptitle("Expressão genética dos genes g-1 à g-9", 
             fontsize=16, 
             fontweight="bold")

# Gerando os gráficos em loop
count=0
mask = list(dados.loc[:, 'g0': 'g9'].columns)
for row in axes:
  for col in row:
    count+=1
    sns.histplot(ax=col, data=dados[mask[count]])

# %%
dados.loc[:, 'c0':'c99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g0' , data=dados)

# %%
plt.figure(figsize = (10 , 8))
sns.boxplot(y='g0', x='tratamento' , data=dados)

# %%
plt.figure(figsize=(18,10))

sns.boxplot(x='tratamento', y='g0' , data=dados)

# %%
plt.figure(figsize=(18,10))

sns.boxplot(x='tempo', y='g0' , data=dados)

# %% [markdown]
# Desafio 04: Estudar sobre as estatíticas retornadas no .describe()
#
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'],
#
# Mean, Média aritmética - É soma de todas as medições divididas pelo número de observações no conjunto de dados.
#
# Std, Standart Desviation ou Desvio padrão - também representado como a letra grega sigma σ é uma medida de dispersão em torno da média populacional de uma variável aleatória. Referência
#
# 50%, median ou Mediana - É uma medida de localização do centro da distribuição dos dados, definida do seguinte modo: ordenados os elementos da amostra, a mediana é o valor (pertencente ou não à amostra) que a divide ao meio, isto é, 50% dos elementos da amostra são menores ou iguais à mediana e os outros 50% são maiores ou iguais à mediana.
#
# 25%, percentile ou 1º quartil - É uma medida de localização do 1/4 dos dados, de forma similar a mediana tem como objetivo encontrar os elementos que são igual a 25% ou menor.
#
# 75% ou 3º quartil - É uma medida de localização do 3/4 dos dados, de forma similar a mediana tem como objetivo encontrar os elementos que são igual a 75% ou maior.
#
# Min e Max, Mínimo e Máximo - São numeros absolutos encontrados o menor e maior valor, ou 0% e 100% definindo assim o intervalo total da amostra.

# %% [markdown]
# #Aula 03
#
# CORRELAÇÕES, CAUSALIDE E RELAÇÕES ENTRE GENES
#
# O foco foi aprofundar ainda mais na base de dados e entender mais sobre a relação entre as variáveis.
#
# Olhando para o conjunto de dados, percebeu-se que há dados de tratamento, tempo, dosagem, composto químico usado e os dados genéticos. E os primeiros dados que foram relacionados foram aqueles ligados ao tratamento, ou seja, dados categóricos.
#
# Um dos vieses de análise foi relacionado às proporções destas categorias, dessa forma, um gráfico de frequências foi muito útil nesse aspecto.

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
sns.scatterplot(x='g0', y='g3', data=dados)

# %%
sns.scatterplot(x='g0', y='g8', data=dados)

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color':'red'})

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color':'red'}, col='tratamento')

# %%
dados.loc[:, 'g0': 'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
dados.loc[:, 'g0': 'g8'].corr()
# Out:
#           g0        g1        g2  ...        g6        g7        g8
# g0  1.000000  0.086032  0.176188  ...  0.238348 -0.374451 -0.604212
# g1  0.086032  1.000000 -0.054518  ... -0.122541  0.144537 -0.009973
# g2  0.176188 -0.054518  1.000000  ...  0.015190 -0.144205 -0.128029
# g3  0.011266 -0.027855  0.042633  ... -0.043177 -0.175692 -0.086167
# g4  0.403153  0.193647  0.013968  ...  0.206405 -0.032748 -0.474828
# g5 -0.165478 -0.151590  0.018516  ...  0.083620  0.102345  0.073885
# g6  0.238348 -0.122541  0.015190  ...  1.000000  0.030544 -0.212292
# g7 -0.374451  0.144537 -0.144205  ...  0.030544  1.000000  0.278085
# g8 -0.604212 -0.009973 -0.128029  ... -0.212292  0.278085  1.000000
#
# [9 rows x 9 columns]

# %%
corr= dados.loc[:, 'g0': 'g50'].corr()

# %%
import numpy as np

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular= dados.loc[:, 'c0': 'c50'].corr()

# %%
import numpy as np

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ####Desafio 01: Criar tabelas de frequencia com o pandas.groupby()

# %%
# Agregando com a contagem de composto para cada index e dividindo pelo número total de experimento;
# Multiplicando por 100 para porcentagem e arredondando para 2 casas decimais.
round(dados.groupby(by=['dose', 'tempo', 'tratamento']).count()[['composto']] / dados.shape[0] * 100, 2)
# Out:
#                          composto
# dose tempo tratamento
# D1   24    com_controle      1.26
#            com_droga        15.05
#      48    com_controle      1.44
#            com_droga        16.84
#      72    com_controle      1.29
#            com_droga        15.12
# D2   24    com_controle      1.28
#            com_droga        15.04
#      48    com_controle      1.28
#            com_droga        15.08
#      72    com_controle      1.28
#            com_droga        15.03

# %%
# Aplicando o unstack() para desagregar o tratamento
dados.groupby(by=['dose', 'tempo', 'tratamento']).count()[['composto']].unstack()
# Out:
#                composto
# tratamento com_controle com_droga
# dose tempo
# D1   24             301      3585
#      48             343      4011
#      72             307      3600
# D2   24             305      3581
#      48             305      3591
#      72             305      3580

# %% [markdown]
# ####Desafio 02: Normalizar o crosstab pela coluna

# %%
# Usando o parâmetro normalize='columns' para obter a frequencia pela coluna.
pd.crosstab(index=[dados['dose'], dados['tempo']], columns=dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ####Desafio 03: Explorar outros agregadores

# %%
# Explorando em loop outros agreadores no crosstab
mask=['min', 'max', 'mean', 'std']
for func in mask:
  print('\n', func)
  print(pd.crosstab(index  = [dados.dose, dados.tempo], 
                    columns= dados.tratamento, 
                    values = dados['g0'], aggfunc=func))
# Out:
#  min
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513
#
#  max
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000
#
#  mean
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439
#
#  std
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.751395   1.461954
#      48         0.853396   1.693903
# ...

# %% [markdown]
# ####Desafio 04: Explorar o Melt

# %%
# O pd.melt() "derrete" as colunas "value_vars" 
# pivotando ela em apenas uma coluna enquanto mantém as outras com id_vars.

columns=dados.loc[:, 'g0': 'g9'].columns
pd.melt(dados, id_vars=['dose', 'tempo', 'tratamento'], value_vars=columns)
# Out:
#        dose  tempo    tratamento variable   value
# 0        D1     24     com_droga       g0  1.0620
# 1        D1     72     com_droga       g0  0.0743
# 2        D1     48     com_droga       g0  0.6280
# 3        D1     48     com_droga       g0 -0.5138
# 4        D2     72     com_droga       g0 -0.3254
# ...     ...    ...           ...      ...     ...
# 238135   D2     24     com_droga       g9  0.1269
# 238136   D2     24     com_droga       g9  0.6727
# 238137   D2     48  com_controle       g9  0.4865
# 238138   D1     24     com_droga       g9 -0.7985
# 238139   D1     72     com_droga       g9  1.2460
#
# [238140 rows x 5 columns]

# %%
#Usando o melt para descobrir o composto com maiores expressoes.
pd.melt(dados, id_vars='g0', value_vars='composto').sort_values(by='g0')
# Out:
#            g0  variable      value
# 726    -5.513  composto  d1d4140f4
# 7834   -5.420  composto  82a5720b8
# 1128   -5.261  composto  2002e6125
# 5117   -5.233  composto  b4c9484ae
# 19974  -5.183  composto  53d56037b
# ...       ...       ...        ...
# 18144  10.000  composto  87d714366
# 19405  10.000  composto  87d714366
# 119    10.000  composto  87d714366
# 4051   10.000  composto  87d714366
# 2428   10.000  composto  87d714366
#
# [23814 rows x 3 columns]

# %% [markdown]
# ####Desafio 05: Calcular e analisar a correlação entre G e C

# %%
corr_GenCel = dados.loc[:, 'g0':'g7'].merge(dados.loc[:, 'c0':'c7'], on=dados['id']).corr()
corr_GenCel
# Out:
#           g0        g1        g2  ...        c5        c6        c7
# g0  1.000000  0.086032  0.176188  ... -0.629189 -0.669697 -0.608954
# g1  0.086032  1.000000 -0.054518  ... -0.004664 -0.027941 -0.003155
# g2  0.176188 -0.054518  1.000000  ... -0.170701 -0.181008 -0.175473
# g3  0.011266 -0.027855  0.042633  ... -0.054947 -0.118651 -0.031232
# g4  0.403153  0.193647  0.013968  ... -0.384914 -0.364633 -0.378776
# g5 -0.165478 -0.151590  0.018516  ...  0.203880  0.192688  0.175350
# g6  0.238348 -0.122541  0.015190  ... -0.080601 -0.077305 -0.095393
# g7 -0.374451  0.144537 -0.144205  ...  0.537956  0.588667  0.489653
# c0 -0.624116 -0.037405 -0.168656  ...  0.844469  0.811946  0.793171
# c1 -0.624810 -0.030558 -0.178692  ...  0.869569  0.876924  0.793199
# c2 -0.639789 -0.039616 -0.176733  ...  0.882794  0.898819  0.812980
# c3 -0.604041  0.011899 -0.156894  ...  0.829550  0.805506  0.752940
# c4 -0.606231 -0.027014 -0.180127  ...  0.883526  0.893285  0.808096
# ...

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)

mask = np.zeros_like(corr_GenCel)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr_GenCel, mask=mask, cmap=cmap, center=0,
                     linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.lmplot(data=dados, x='g0', y='c6', markers='.', 
           line_kws={'color':'r'}, hue='tratamento');

# %% [markdown]
# #Aula 04
#
# MERGE DE DADOS E ANÁLSES DE RESULTADOS
#
# Foram combinadas as duas bases de dados, a base de dados experimentais com a base de dados resultados, para tanto, foi utilizada a função merge do Pandas. Em seguida, foi analisada a relação entre algumas informações da base de dados experimentais e resultados utilizando o boxplot. Por fim, houve uma descrição mais detalhada do que é o mecanismo de ação (MoA) de uma droga.

# %%
dados_resultados = pd.read_csv('https://github.com/palomaalves/imersao.dados-alura/blob/main/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
contagem_moa1 = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa1
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa1 = dados_resultados.drop('id', axis=1).sum(axis=1)
contagem_moa1
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.drop('id' , axis = 1).sum(axis = 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['n_moa1'] = dados_resultados.drop('id', axis = 1).sum(axis = 1)
dados_resultados['ativo_moa1'] = (dados_resultados['n_moa1'] != 0)

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa1  ativo_moa1
# 0  id_000644bb2                            0  ...       1        True
# 1  id_000779bfc                            0  ...       0       False
# 2  id_000a6266a                            0  ...       3        True
# 3  id_0015fd391                            0  ...       0       False
# 4  id_001626bd3                            0  ...       1        True
#
# [5 rows x 209 columns]

# %% [markdown]
# ##MERGE

# %%
dataset_merge=pd.merge(dados, dados_resultados[['id','n_moa1', 'ativo_moa1']], on='id')
dataset_merge.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa1  ativo_moa1
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176       1        True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371       0       False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931       3        True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154       0       False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125       1        True
#
# [5 rows x 879 columns]

# %%
dataset_merge.query('tratamento == "com_controle" ')['ativo_moa1'].value_counts()
# Out:
# False    1866
# Name: ativo_moa1, dtype: int64

# %% [markdown]
# ###Desafio: Criar uma coluna 'eh_controle' para quando na linha tratamento == com_ontrole

# %% [markdown]
# Criando uma nova coluna e comparando o conteúdo da coluna tratamento com o texto esperado, retornando um resultado booleano

# %%
dataset_merge['eh_controle'] = dataset_merge['tratamento'] == 'com_controle'

# %%
dataset_merge.head()
# Out:
#              id tratamento  tempo dose  ...     c99  n_moa1  ativo_moa1  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176       1        True        False
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371       0       False        False
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931       3        True        False
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154       0       False        False
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125       1        True        False
#
# [5 rows x 880 columns]

# %% [markdown]
# Algum com_controle ativou algum MOA, podemos ver que nenhum MOA foi ativado nesses testes

# %%
controle_true = dataset_merge.query('eh_controle == True')
controle_true['ativo_moa1'].unique()
# Out:
# array([False])

# %% [markdown]
# ### Dasafio: Encontrar o top 10, das ações do MOA (inibidor, agonista...)

# %%
nomes_moa = dados_resultados.columns

df_moa = pd.DataFrame(nomes_moa)

i, n = 1, 6
while i < n:
  df_moa = df_moa.replace(r'^.*?_','', regex=True)
  i += 1

top_moa = df_moa.value_counts()[:10]
top_moa
# Out:
# inhibitor         112
# antagonist         32
# agonist            28
# activator           5
# agent               3
# moa1                2
# blocker             2
# anticonvulsant      1
# antihistamine       1
# antifungal          1
# dtype: int64

# %% [markdown]
# ####Desafio: Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %%
dataset_merge.loc[0,'tratamento']
# Out:
# 'com_droga'

# %%
for i in range(0,len(dataset_merge)):
  if dataset_merge.loc[i,'tratamento']=='com_controle':
    dataset_merge.loc[i,'eh_controle'] = 1
  else:
    dataset_merge.loc[i,'eh_controle'] = 0

# %%
dataset_merge[['tratamento','eh_controle']]
# Out:
#          tratamento eh_controle
# 0         com_droga           0
# 1         com_droga           0
# 2         com_droga           0
# 3         com_droga           0
# 4         com_droga           0
# ...             ...         ...
# 23809     com_droga           0
# 23810     com_droga           0
# 23811  com_controle           1
# 23812     com_droga           0
# 23813     com_droga           0
#
# [23814 rows x 2 columns]

# %%
dataset_merge.query('tratamento == "com_droga" ')['ativo_moa1'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa1, dtype: int64

# %%
lista_analise = ['cacb2b860','87d714366']

plt.figure(figsize=(12,8))
sns.boxplot(data = dataset_merge.query('composto in @lista_analise'), y= 'g0', x='composto', hue='dose')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data = dataset_merge.query('composto in @lista_analise'), y= 'g0', x='composto', hue='tempo')

# %%
compostos_principais = dataset_merge['composto'].value_counts().index[:5]
compostos_principais
plt.figure(figsize=(12,8))
sns.boxplot(data=dataset_merge.query('composto in @compostos_principais'), y='g0', x='composto', hue='ativo_moa1')

# %% [markdown]
# ###Desafio: Criar três colunas para indicar o tempo 24, 48, 72

# %% [markdown]
# Criando novas coluna e comparando o conteúdo da coluna tempo com o número esperado, retornando um resultado booleano

# %%
dataset_merge['tempo_24'] = dataset_merge['tempo'] == 24
dataset_merge['tempo_48'] = dataset_merge['tempo'] == 48
dataset_merge['tempo_72'] = dataset_merge['tempo'] == 72

# %%
dataset_merge.head()
# Out:
#              id tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0  id_000644bb2  com_droga     24  ...     True    False     False
# 1  id_000779bfc  com_droga     72  ...    False    False      True
# 2  id_000a6266a  com_droga     48  ...    False     True     False
# 3  id_0015fd391  com_droga     48  ...    False     True     False
# 4  id_001626bd3  com_droga     72  ...    False    False      True
#
# [5 rows x 883 columns]

# %% [markdown]
# ####Desafio: Fazer análise mais detalhada considerando tempo e dose, para comparar as **distribuições**

# %%
dataset_merge[['tratamento','composto']].value_counts()
# Out:
# tratamento    composto
# com_controle  cacb2b860    1866
# com_droga     87d714366     718
#               9f80f3f77     246
#               8b87a7a83     203
#               5628cb3ee     202
#                            ...
#               b3f24a171       1
#               1502f8cbb       1
#               36dc71f82       1
#               b472193a9       1
#               547f80a41       1
# Length: 3289, dtype: int64

# %%
composto_ativa_moa = dataset_merge.query('ativo_moa1 == True')
composto_nao_ativa_moa = dataset_merge.query('ativo_moa1 == False')

composto_ativa_nao_ativa = pd.merge(composto_ativa_moa, composto_nao_ativa_moa, on=['composto'], how='outer', indicator=True)

# %%
composto_ativa_nao_ativa['_merge'].value_counts()
# Out:
# left_only     14447
# right_only     9367
# both              0
# Name: _merge, dtype: int64

# %% [markdown]
# Documentação do Merge https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html#pandas.DataFrame.merge
# Importante observar a condição "on = ", ela é a nossa chave primária e deve ser igual nos dois dataframes.

# %%
composto_controle = dataset_merge.query('composto == "cacb2b860"')
composto_droga = dataset_merge.query('composto == "87d714366"')

# %%
q = composto_controle.shape[0]
print(f'Temos no total {q} testes com o Controle, sua divisão em dose e tempo é:')
composto_controle.groupby('dose')['tempo'].value_counts().unstack()
# Out:
# Temos no total 1866 testes com o Controle, sua divisão em dose e tempo é:
# tempo   24   48   72
# dose
# D1     301  343  307
# D2     305  305  305

# %%
q = composto_droga.shape[0]
print(f'Temos no total {q} testes com o composto 87d714366, sua divisão em dose e tempo é:')
composto_droga.groupby('dose')['tempo'].value_counts().unstack()
# Out:
# Temos no total 718 testes com o composto 87d714366, sua divisão em dose e tempo é:
# tempo   24   48   72
# dose
# D1     121  131  123
# D2     114  116  113

# %% [markdown]
# ###Desafio: Descobrir se temos algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %%
composto_ativa_moa = dataset_merge.query('ativo_moa1 == True')
composto_nao_ativa_moa = dataset_merge.query('ativo_moa1 == False')

composto_ativa_nao_ativa = pd.merge(composto_ativa_moa, composto_nao_ativa_moa, on=['composto'], how='outer', indicator=True)

# %%
composto_ativa_nao_ativa['_merge'].value_counts()
# Out:
# left_only     14447
# right_only     9367
# both              0
# Name: _merge, dtype: int64

# %% [markdown]
# ### Desafio: Descobrir se temos algum composto que dependendo da configuração do experimento, ativa MOAs diferentes

# %%
moa_ativados = dataset_merge.query('ativo_moa1 > 0')
moa_ativados['composto'].value_counts()
# Out:
# 87d714366    718
# 9f80f3f77    246
# 8b87a7a83    203
# 5628cb3ee    202
# d08af5d4b    196
#             ...
# 6e418401d      1
# d75904698      1
# 5cc5a5a19      1
# f19d8c43b      1
# e3e768009      1
# Name: composto, Length: 2076, dtype: int64

# %% [markdown]
# #AULA 5
#
# MACHINE LEARNING, SCI-KIT LEARNING E DESAFIOS ENVOLVIDOS
#
# Foi criado o primeiro modelo de **Machine Learning** para classificar um novo composto com o intuito de prever se o MoA foi ativado ou não. Para isso, foi usado a famosa biblioteca scikit-learn para testar a regressão logística e entender o funcionamento de uma árvore de decisão (AD).

# %% [markdown]
# ***“Machine learning is the field of study that gives computers the ability to learn without being explicitly programmed” – (definição clássica de Arthur Samuel, cientista da computação, 1959)***
#
# *Tradução livre: "Machine Learning é um campo de estudo que dá aos computadores a habilidade de aprender sem terem sido programados para tal."*
#
# Pode-se interpretar a definição de Samuel, da seguinte forma: para que um computador reconheça determinada imagem, não precisamos passar um conjunto de regras, mostrar vários exemplos é suficiente para que o computador classifique suas imagens. Sendo assim, há dois fatores determinantes neste processo: um conjunto de dados suficientemente grande e um poder computacional elevado. Por isso, até os anos 2000, era bem difícil encontrar problemas significantes resolvidos através do Machine Learning. Mas, a partir de 2009, empresas como a Netflix e Amazon, começaram a resolver problemas reais com o processamento dos dados através no ML, isso porque tinham uma infinidade de dados disponíveis e alto poder computacional.
#
# E quais problemas pode-se resolver com esse tipo de algoritmo? Existem diversos casos em que podemos aplicá-los mas, vamos subdividir em dois grandes grupos:
#
#     - Problemas em que somos muito bons em resolver mas o Machine Learning, leva essa produção à um nível industrial, como é o caso da classificação de imagens
#     - Problemas em que não somos tão bons em resolver e o Machine Learning pode tomar uma melhor decisão em relação à nossa (imparcialidade, pode ser um fator), como é o caso da concessão de crédito.
#
# Mas como o Machine Learning vai ser aplicado no problema?
# Bom, utilizando a nossa base de dados ```dataset_merge```, o primeiro problema para resolver é: **dado os experimentos, pode saber se qualquer mecanismo de ação foi ativado ou não ativado.** Ou seja, este caso é um problema de classificação binária.
#
# Mas, também pode-se pensar se **dado os experimentos, se quer saber se um determinado mecanismo de ação foi ativado, recebendo como resposta, o composto relacionado**. E aqui, temos um problema de classificação multiclasse, já que cada composto químico é considerado uma classe diferente.

# %%
dataset_merge.head()
# Out:
#              id tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0  id_000644bb2  com_droga     24  ...     True    False     False
# 1  id_000779bfc  com_droga     72  ...    False    False      True
# 2  id_000a6266a  com_droga     48  ...    False     True     False
# 3  id_0015fd391  com_droga     48  ...    False     True     False
# 4  id_001626bd3  com_droga     72  ...    False    False      True
#
# [5 rows x 883 columns]

# %% [markdown]
# Na base dados_resultados se encontra o ID do composto e quais mecanismos de ação foram acionados por determinado experimento. Aqui, como um composto pode acionar mais de um mecanismo, tem-se uma classificação multilabel (quando uma única instância pode ter mais de uma classe associada) e, através de um algoritmo de Machine Learning pode-se resolver este problema: não somente ter como retorno se um mecanismo de ação foi ativado mas qual ou quais são estes mecanismos.
#
# É importante lembrar que as bases de dados estão separadas com um propósito. A segunda dados_resultados é como se fosse a resposta da primeira e foi construída por cientistas que analisaram o efeito de um determinado composto nos mais de 700 genes. Esse conhecimento, virou uma base de dados com o passar dos anos e é fruto de análise científica.
#
# E o papel de um modelo de ML neste caso é, a partir de todo esforço humano empenhado por vários anos para entender e tabular qual efeito de um composto quimíco em uma determinada expressão gênica, ser treinado e aprender, ou seja, ser capaz de produzir resultados compatíveis com aqueles feitos pelos(as) próprios(as) cientistas.
# A classificação binária: dado os experimentos, se quer saber se QUALQUER mecanismo de ação foi ativado ou não. Basicamente, quer que o modelo faça predições compatível com a última coluna da nossa base de dados dataset_merge, a ativo_moa1
#
# Dado um composto -> temos a assinatura celular (```g e c```) -> foi analisado o(s) mecanismo(s) de ação ativados (MoA)
#
# Composto 1 -> Assinatura A -> MoA = 1
# Composto 2 -> Assinatura B -> MoA = 0
# Composto 3 -> Assinatura C -> MoA = 1
# ...
# Composto N -> Assinatura N -> MoA = 0
#
# Ou seja, toda a base de dados dataset_merge será a fonte de aprendizado do modelo. Onde, cada experimento (linha) representa um exemplo (assinatura) já que tem a reunião de todas as informações necessárias para criar a classificação binária e, terá como variável resposta, também chamada de target, a coluna ativo_moa, uma variável binária (0, 1)
#
# Existem diversas técnicas de ML que são capazes de solucionar o problema mas aqui, foi usado a Regressão Logística e, essa técnica já está implementada em uma biblioteca bastante usada e bem importante para ML no Python, o Scikit-Learn.
#
# Quando se implementa um modelo de classificação, precisamos separar a base de dados em base de treino e base de teste. A base de treino, vai ser onde o modelo vai aprender e, a base de teste serve para a verificação do aprendizado do modelo, ou seja, pode-se, de fato, verificar se as previsões do modelo estão de acordo com o esperado.
#
# Para fazer a divisão da base de dados, é necessário definir qual será o x e o y. Um modelo matemático, define um y em função de um x, ou seja, f(x) = y. Neste projeto, o y será o target, ativo_moa e, ele será definido a partir de uma assinatura (conjunto composto por g + c ou , expressão gênica + viabilidade celular).
#
# Assim, teremos:
#
# x = dataset_merge.select_dtypes('float64')  ->  toda a base de dados que tem os valores com o formato, ```float64```, no caso, todas as variáveis ```g``` e ```c```
#
# y = dataset_merge['ativo_moa1']  ->  apenas a coluna target, ou seja, ```ativo_moa```

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x= dataset_merge.select_dtypes('float64')
y= dataset_merge['ativo_moa1']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2)


train_test_split(x,y)
# Out:
# [           g0      g1      g2      g3  ...     c96     c97     c98     c99
#  15226 -0.7447 -0.5925 -0.3962  0.7982  ... -0.4668  0.2089  0.8657 -0.8454
#  18124  0.3107  0.2803 -0.8034 -0.6417  ... -0.2369 -1.2180 -0.5808  0.0170
#  15100 -1.0200 -0.0314 -0.5164 -0.2944  ...  0.5972  0.6724  0.4398  0.0614
#  2847  -0.2331  0.5351 -0.4911 -0.4074  ...  1.3540 -0.2572  1.8250  0.5588
#  12069  0.7121  0.3082 -0.0237  0.9075  ... -0.1975 -0.5465 -0.5714  0.3134
#  ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
#  11854 -0.6852 -0.8128  1.0840  0.1835  ...  0.1427  0.1498  0.0465  0.0748
#  15003  2.7040  0.6695  1.4020 -0.7905  ... -7.6660 -6.5580 -2.8070 -1.7990
#  19368 -0.7528  0.4162 -0.5051  1.3180  ... -0.6856 -0.3556 -0.7277 -0.9952
#  23802  3.2890  2.1270  0.9770  2.0490  ... -8.4480 -4.4550 -5.7930 -3.7000
#  3601  -0.9711 -0.7190 -0.1135 -0.5946  ...  0.5874 -0.0500 -0.0609  0.5589
#
#  [17860 rows x 872 columns],
# ...

# %%
x= dataset_merge.select_dtypes('float64')
y= dataset_merge['ativo_moa1']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.2)

modelo_rlogistica  = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino,y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6344740709636784

# %% [markdown]
# Para estabelecer se há um bom valor de acurácia, precisou de uma base comparativa, quer dizer, precisou-se dos resultados de um outro modelo para entender se estava acertando mais ou menos casos.
#
# Para isso, o Scikit-Learn, já tem implementado alguns algoritmos para modelos menos complexos e que podem ser usados como base comparativa. Neste caso, foi usado o DummyClassifier.
#
# Ao instanciar o DummyClassifier, precisou-se definir a estratégia que ele usará para fazer o ajuste do modelo. No caso, definiu-se que a estratégia foram os dados mais frequentes, isso quer dizer que: dado o valor mais frequente da variável resposta (ativo_moa), o modelo Dummy vai chutar que todos os eventos da base de dados assumem aquele valor no target. Assim: DummyClassifier('most_frequent').
#
# Nesse momento, para calcular a acurácia, foi usado outra estratégia, a função accuracy_score também do Scikit-Learn. Ela recebeu como parâmetros a base teste da variável resposta (y_teste) e as previsões do modelo. Para calcular as previsões, usou-se o .predict() da mesma biblioteca, que recebeu como parâmetro a base x_teste.
#
# Por fim, o cálculo da acurácia foi
# previsao_dummy = modelo_dummy.predict(x_teste)
# accuracy_score(y_teste, previsao_dummy)

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy= DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy=modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6080201553642662

# %%
dataset_merge['ativo_moa1'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa1, dtype: float64

# %% [markdown]
# Foi verificado que a acurácia do DummyClassifier de 60%, uma vez que com um value_counts normalizado e proporção entre a classe 0 e a classe 1 encontra-se 60/30, ou seja, o valor mais frequente (estratégia usada no DummyClassifier). Isso quer dizer que, caso o modelo chutasse a mesma classe para todos os eventos da base de teste, acertaria de 60% dos casos.

# %% [markdown]
# O train_test_split a base de dados em subconjuntos aleatórios de treino e teste. Isso significa que toda vez que você executá-lo, se obtem um resultado diferente.
#
# Por outro lado, ao declarar o parâmetro random_state = n, pode-se garantir que a saída de todas as execuções serão iguais.
#
# Além do random_state, existe mais um parâmetro bem importante que deve ser levado em consideração na divisão da base de dados, o stratify.
#
# Para que as bases de treino e teste sigam, além de uma divisão reprodutível (garantida com random_state), a proporção original do conjunto de dados é necessário a  atribuição do stratify = coluna.
#
# Esses parâmetros são úteis, porque garante-se que os resultados são reproduzíveis e compatíveis, independente do modelo (qual técnica, por exemplo, regressão logística, dummy classifier, árvore de decisão e etc) que será treinada e testada a partir desta divisão.
#
# Ou seja, ao final, o train_teste_split ficará:
#
# x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x= dataset_merge.select_dtypes('float64')
y= dataset_merge['ativo_moa1']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_rlogistica  = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino,y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy= DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy=modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %% [markdown]
# Foram exploraadas outras técnicas de modelagem para comparar os resultados obtidos e ver qual o melhor algoritmo que conseguimos produzir.
#
# A árvore de decisão: DecisionTreeClassifier, também da biblioteca Scikit-Learn. O único parâmetro que foi declarado para esta função foi o max_depth = 3.
#
# Como resultado foi obtido uma acurácia (calculada a partir da base de teste) de aproximandamente 61%, um pouco menor do que a acurácia obtida com a regressão logística.

# %%
from sklearn.tree import DecisionTreeClassifier

x = dataset_merge.select_dtypes('float64')
y = dataset_merge['ativo_moa1'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %% [markdown]
# Foi plotada uma imagem que representa o modelo de árvore de decisão.
#
# A figura é dividida em 4 níveis e, o primeiro nível é composto por apenas um quadro que é chamado de nó raíz ou somente raíz e ele tem como regras, os melhores atributos que podem dividir a base de dados em dois conjuntos distintos (lembrando que objetivo é separar a base de dados em mecanismo de ação ativado ou não ativado).
#
# Entre o primeiro e o segundo nível (e nos demais níveis), tem duas setas: uma para a direita e outra para a esquerda. Essas setas são chamadas de ramos e subdividem o nível acima em dois outros conjuntos que separam novamente os dados em mecanismo de ação ativado ou não ativado, a partir de uma decisão.
#
# O último nível da árvore (mais abaixo), apresenta n quadros que apresentam características que devem ser levadas em conta na hora da classificação e se dividem em class = ativado e class = não ativado. Esse nível não apresenta mais ramificações e, esses quadros são chamados de folhas.
#
# A árvore tem 3 níveis de decisão a partir da raíz e é exatamente isso que o parâmetro max_depthrepresenta: a profundidade da árvore.

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15, 10), facecolor='k')
tree.plot_tree(modelo_arvore,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=x_treino.columns,
               class_names=['Não Ativado', 'Ativado'])

plt.show()

# %% [markdown]
# Como o desempenho foi ruim, foi alterado o ```max_depth``` dentro de um intervalo de valores (range) e comparados os resultados obtidos.
#
# O processo para obter os valores é sempre o mesmo. Foi criado um loop ou um laço de repetição.
#
# teste=[]  ->  criando lista para armazenar os resultados da acurácia nos dados de teste
# treino=[]  ->  criando lista para armazenar os resultados da acurácia nos dados de treino
#
# for i in range(1,15):  ->  estabelecendo condição que deve ser atendida (i) e range de valor (range(1, 15))
#     modelo_arvore = DecisionTreeClassifier(max_depth = i)  ->  instanciando modelo que será treinado e definindo max_depth = i, ou seja, variando a profundidade da árvore
#     modelo_arvore.fit(x_treino, y_treino)  ->  ajustando o modelo a partir das bases de treino
#     teste.append(modelo_arvore.score(x_teste, y_teste))  ->  armazenando os resultados de acurácia de teste dos modelos produzidos na lista 'teste'
#     treino.append(modelo_arvore.score(x_treino, y_treino))  ->  armazenando os resultados de acurácia de treino dos modelos produzidos na lista 'treino'

# %%
from sklearn.tree import DecisionTreeClassifier

x = dataset_merge.select_dtypes('float64')
y = dataset_merge['ativo_moa1'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

teste=[]
treino=[]

for i in range(1,10):
    modelo_arvore = DecisionTreeClassifier(max_depth = i)
    modelo_arvore.fit(x_treino, y_treino)
    teste.append(modelo_arvore.score(x_teste, y_teste))
    treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6208272097417594,
#  0.6208272097417594,
#  0.6180978374973756,
#  0.6218769682972917,
#  0.6197774511862272,
#  0.6180978374973756]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6606477350270327,
#  0.6707259461445594,
#  0.6895176106241142]

# %%
sns.lineplot(x=range(1,10), y= teste, label= 'teste')
sns.lineplot(x=range(1,10), y= treino, label= 'treino')

# %% [markdown]
# Pode-se perceber que, inicialmente, os valores de treino e teste são muito próximos mas, conforme vai aumentando o range, o valor da acurácia para os dados de treino aumentam muito enquanto, esse mesmo valor para os dados de teste, vai caindo (as linhas vão se afastando). Isso significa que, conforme aumenta-se a profundidade da nossa árvore de decisão, a classificação para os dados de treino ficam muito boas pois, ela consegue captar muito bem as características desses dados. Mas, em contrapartida, o modelo fica tão bom os dados de treino que, quando foi apresentado um novo conjunto de dados (teste), ele não consegue generalizar tão bem e assim, daí se tem uma acurácia em queda.
# Esse problema de um modelo com performance muito boa nos dados de treino mas performance em queda nos dados de teste, é muito conhecido na ciência de dados e chamamos de **overfitting**.

# %% [markdown]
# Para melhorar o modelo não é suficiente somente aumentar a profundidade da árvore de decisão. Dessa forma, foi testada uma nova técnica de modelagem: o **Random Forest**. O que este modelo faz é criar várias árvores de decisões na qual ele considera amostras aleatórias do nosso conjunto total.
#
# A função que treina um modelo de Random Forest (```RandomForestClassifier()```) não aceita variáveis em formato de string.
# Por isso, é necessário tratar as variáveis que são strings e transformá-las em números (ou no formato float64).
#
# Para fazer essa transformação, foi usaado uma função do Pandas, chamada ```get_dummies``` e nela, foi declarada a coluna que queremos que seja transformada. Por exemplo, aqui, usou-se:
#
#     pd.get_dummies(dataset_merge['tratamento'])
#
# Isso porque, a intenção é transformar a coluna ```tratamento``` da base ```dataset_merge``` em dados numéricos.
#
# Para fazer a transformação desejada, o ```get_dummies``` pega todas as categorias de uma variável e as transforma em novas colunas binárias.
# Por exemplo:
#
# A variável ```tratamento``` apresenta duas categorias ```com_controle``` e ```sem_controle```. Ao aplicar o ```get_dummies```, ele cria duas novas colunas binárias e análogas as categorias.
# Na coluna original a marcação com_droga, apresentará valor 0, na coluna ```com_controle``` e valor 1 na coluna ```com_droga```.

# %%
pd.get_dummies(dataset_merge['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dataset_merge, columns=['tratamento', 'dose', 'tempo'])
# Out:
#                  id   composto      g0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 887 columns]

# %% [markdown]
# 'id'  ->  não será relevante nesse momento pois é somente um número de identificação
# 'n_moa'  ->  não será relevante nesse momento pois é a quantidade de MoAs ativados
# 'ativo_moa'  ->  retiramos da base pois é a nossa variável resposta
# 'composto'  ->  não será relevante nesse momento pois identifica o composto usado e foge do que estamos buscando fazer
# Para retirar essas variáveis da nossa base de dados, usa-se a função drop, declaram-se as variáveis a serem retiradas em forma de uma lista e identifica-se que são colunas através do parâmetro axis = 1.

# %%
dataset_merge.drop(['id', 'n_moa1', 'ativo_moa1', 'composto'], axis=1)
# Out:
#          tratamento  tempo dose  ...  tempo_24  tempo_48  tempo_72
# 0         com_droga     24   D1  ...      True     False     False
# 1         com_droga     72   D1  ...     False     False      True
# 2         com_droga     48   D1  ...     False      True     False
# 3         com_droga     48   D1  ...     False      True     False
# 4         com_droga     72   D2  ...     False     False      True
# ...             ...    ...  ...  ...       ...       ...       ...
# 23809     com_droga     24   D2  ...      True     False     False
# 23810     com_droga     24   D2  ...      True     False     False
# 23811  com_controle     48   D2  ...     False      True     False
# 23812     com_droga     24   D1  ...      True     False     False
# 23813     com_droga     72   D1  ...     False     False      True
#
# [23814 rows x 879 columns]

# %% [markdown]
# x = dataset_merge.drop(['id', 'n_moa1', 'ativo_moa1', 'composto'], axis=1)  ->  base de dados de deve ser considerada com a exclusão das colunas
# x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])  ->  a partir do x definido acima, faz a transformação com o get_dummies nas colunas com o formato de string

# %%
from sklearn.ensemble import RandomForestClassifier

x = dataset_merge.drop(['id', 'n_moa1', 'ativo_moa1', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo']) 
y = dataset_merge['ativo_moa1'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_random_forest = RandomForestClassifier()
modelo_random_forest.fit(x_treino, y_treino)
modelo_random_forest.score(x_teste, y_teste)
# Out:
# 0.6848624816292253

# %% [markdown]
# Por fim, foi obtida uma acurácia de aproximadamente 68,0% e, ela é, aproximadamente, 7% melhor que a acurácia que conseguimos com o DummyClassifier. Aqui, não se pode comparar com a regressão logística porque foi considerado um outro conjunto de dados.
#
# É muito importante ressaltar que, apesar de ter melhorado a acurácia do modelo, pensando na vida real, talvez a melhora ainda não seja suficiente. Ou seja, foi desenvolvido um modelo com um algoritmo de Machine Learning mas, ele ainda não é aplicável à vida real (isso quer dizer que, ainda não trouxe ganhos suficientes para sua implantação).
#
# Por outro lado, durante todo o projeto, foram apliacados modelos simples e não foram aprofundados em todos os pontos que podem ser modificados (variáveis, parâmetros de modelos, por exemplo) a fim de otimizar a generalização. a.
